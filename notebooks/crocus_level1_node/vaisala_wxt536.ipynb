# %% [markdown]
# # Read Data from a Vaisala WXT536

# %%
import sage_data_client
import matplotlib.pyplot as plt
import pandas as pd

from matplotlib.dates import DateFormatter

# %% [markdown]
# ----

# %% [markdown]
# <img src="../images/Vaisala_WXT536.jpeg" width=250 alt="Vaisala_WXT536"></img>

# %% [markdown]
# ## Overview
#
#
# The Vaisala WXT536 is an multi-parameter weather sensor that measures atmospheric temperatures, pressure, humdity, wind speed and direction, and precipitation.
#
# High quality atmospheric observations allow for understanding of the environmental conditions at the location of the instrument, and allow us to estimate transport of gas and particles through the atmosphere.
#
# In combination with additional sensors attached to a CROCUS Level 1 Node, we are then able to evaluate the concentration of pollutants at the node, the transport of these pollutants into and out of the area of the node, and estimate removal of these pollutants from the atmosphere from preciptiation.

# %% [markdown]
# ## Prerequisites
#
# All WXT-536s are installed into a Waggle Edge Computing server as apart of CROCUS's Level 1 Nodes.
#
# The Waggle Edge Computing server allows for real-time modification of sensors parameters and dynamical modification of data through edge processing codes.
#
# | Concepts | Importance | Notes |
# | --- | --- | --- |
# | [Intro to Waggle Sensors](https://github.com/waggle-sensor) | Helpful | Familiarity with Waggle Sensors|
# | [Waggle/Sage Data Client](https://github.com/sagecontinuum/sage-data-client) | Necessary | Accessing Data |
# | [Working with Pandas Dataframes](https://foundations.projectpythia.org/core/pandas.html) | Necessary | Understanding Data Object
#
# - **Time to Learn**: 60 minutes

# %% [markdown]
# ## Interact with WXT-536 Data
#
# We will be accessing data from a CROCUS Level 1 Node (W057), which is located at the Argonne Testbed for Multiscale Observational Science (ATMOS)
#
# <img src="../images/CROCUS_Level1_Node_WXT.jpeg" width=250 alt="CROCUS Level 1 Node (W057)"></img>

# %% [markdown]
# ATMOS serves as a long term observational site and allows for testing equipment before deployment across the CROCUS domain
#
# Please check the [Waggle Node W08D User Interface](https://crocus.sagecontinuum.org/node/W08D) to determine if the *vaisala-wxt536* plugin is working
#
# The [vaisala-wxt536 plugin](https://github.com/jrobrien91/waggle-wxt536) allows for the Waggle Sensor to interpret data sent from the instrument to the Waggle Node and transit this data to cloud storage for investigation.
#
# To Query data from a Waggle Sensor, we will need:
# 1. Start of time period we are interested in (YYYY-MM-DDTHH:MM:SSZ format)
# 1. End of time period we are interested in (YYYY-MM-DDTHH:MM:SSZ format)
# 1. Plugin Name (e.g. waggle-wxt536)
# 1. Waggle Node Number (e.g. W057)
# 1. Sensor Name (e.g. 'vaisala-wxt536')

# %%
# Query the SAGE data client to access the data
# Note: We need to know the time period we are interested in
df = sage_data_client.query(start="2023-07-02T12:00:00Z",
                            end="2023-07-02T13:00:00Z", 
                            filter={
                                "vsn": "W08D",
                                "sensor": "vaisala-wxt536"
                            }
)

# %%
df
# Out:
#                                  timestamp              name  value  \
# 0      2023-07-02 12:00:00.029156535+00:00  wxt.env.humidity  100.0
# 1      2023-07-02 12:00:00.107252119+00:00  wxt.env.humidity  100.0
# 2      2023-07-02 12:00:00.206164123+00:00  wxt.env.humidity  100.0
# 3      2023-07-02 12:00:00.283311181+00:00  wxt.env.humidity  100.0
# 4      2023-07-02 12:00:00.364271449+00:00  wxt.env.humidity  100.0
# ...                                    ...               ...    ...
# 350859 2023-07-02 12:59:59.600882716+00:00    wxt.wind.speed    1.5
# 350860 2023-07-02 12:59:59.684669667+00:00    wxt.wind.speed    1.5
# 350861 2023-07-02 12:59:59.760763484+00:00    wxt.wind.speed    1.5
# 350862 2023-07-02 12:59:59.841247667+00:00    wxt.wind.speed    1.5
# 350863 2023-07-02 12:59:59.920791677+00:00    wxt.wind.speed    1.5
#
#                          meta.host       meta.job meta.missing  \
# 0       000048b02d3ae277.ws-nxcore  waggle-wxt536      -9999.9
# 1       000048b02d3ae277.ws-nxcore  waggle-wxt536      -9999.9
# 2       000048b02d3ae277.ws-nxcore  waggle-wxt536      -9999.9
# 3       000048b02d3ae277.ws-nxcore  waggle-wxt536      -9999.9
# 4       000048b02d3ae277.ws-nxcore  waggle-wxt536      -9999.9
# ...                            ...            ...          ...
# 350859  000048b02d3ae277.ws-nxcore  waggle-wxt536      -9999.9
# 350860  000048b02d3ae277.ws-nxcore  waggle-wxt536      -9999.9
# 350861  000048b02d3ae277.ws-nxcore  waggle-wxt536      -9999.9
# 350862  000048b02d3ae277.ws-nxcore  waggle-wxt536      -9999.9
# 350863  000048b02d3ae277.ws-nxcore  waggle-wxt536      -9999.9
#
#                meta.node                                        meta.plugin  \
# 0       000048b02d3ae277  registry.sagecontinuum.org/jrobrien/waggle-wxt...
# 1       000048b02d3ae277  registry.sagecontinuum.org/jrobrien/waggle-wxt...
# 2       000048b02d3ae277  registry.sagecontinuum.org/jrobrien/waggle-wxt...
# 3       000048b02d3ae277  registry.sagecontinuum.org/jrobrien/waggle-wxt...
# 4       000048b02d3ae277  registry.sagecontinuum.org/jrobrien/waggle-wxt...
# ...                  ...                                                ...
# 350859  000048b02d3ae277  registry.sagecontinuum.org/jrobrien/waggle-wxt...
# 350860  000048b02d3ae277  registry.sagecontinuum.org/jrobrien/waggle-wxt...
# 350861  000048b02d3ae277  registry.sagecontinuum.org/jrobrien/waggle-wxt...
# 350862  000048b02d3ae277  registry.sagecontinuum.org/jrobrien/waggle-wxt...
# 350863  000048b02d3ae277  registry.sagecontinuum.org/jrobrien/waggle-wxt...
#
#            meta.sensor      meta.task         meta.units meta.vsn meta.zone
# 0       vaisala-wxt536  waggle-wxt536            percent     W08D      core
# 1       vaisala-wxt536  waggle-wxt536            percent     W08D      core
# 2       vaisala-wxt536  waggle-wxt536            percent     W08D      core
# 3       vaisala-wxt536  waggle-wxt536            percent     W08D      core
# 4       vaisala-wxt536  waggle-wxt536            percent     W08D      core
# ...                ...            ...                ...      ...       ...
# 350859  vaisala-wxt536  waggle-wxt536  meters per second     W08D      core
# 350860  vaisala-wxt536  waggle-wxt536  meters per second     W08D      core
# 350861  vaisala-wxt536  waggle-wxt536  meters per second     W08D      core
# 350862  vaisala-wxt536  waggle-wxt536  meters per second     W08D      core
# 350863  vaisala-wxt536  waggle-wxt536  meters per second     W08D      core
#
# [350864 rows x 13 columns]

# %%
# Detemine the number of rows within the dataset
df.index
# Out:
# RangeIndex(start=0, stop=350864, step=1)

# %%
# Determine number of columns within dataset
df.columns
# Out:
# Index(['timestamp', 'name', 'value', 'meta.host', 'meta.job', 'meta.missing',
#        'meta.node', 'meta.plugin', 'meta.sensor', 'meta.task', 'meta.units',
#        'meta.vsn', 'meta.zone'],
#       dtype='object')

# %%
# Determine the number of unique measurements within 'name' column
print(set(df['name']))
# Out:
# {'wxt.env.humidity', 'wxt.heater.volt', 'wxt.rain.accumulation', 'wxt.heater.temp', 'wxt.env.pressure', 'wxt.wind.direction', 'wxt.wind.speed', 'wxt.env.temp'}

# %% [markdown]
# <div class="admonition alert alert-danger">
#     <p class="admonition-title" style="font-weight:bold">Danger</p>
#     Data will only be returned for valid dates. Otherwise, dataframe object will contain nothing
# </div>

# %%
# Query the SAGE data client to access the data
# Note: We need to know the time period we are interested in
no_data_df = sage_data_client.query(start="2099-04-10T12:00:00Z",
                                    end="2099-04-10T15:00:00Z", 
                                    filter={
                                        "vsn": "W08D",
                                        "sensor": "vaisala-wxt536"
                                    }
)

# %%
no_data_df
# Out:
# Empty DataFrame
# Columns: [timestamp, name, value]
# Index: []

# %% [markdown]
# ## Investigate the Dataset
#
# To investigate the dataset, it is helpful to know how to access specific rows or columns within the data
#
# We will then display the ambient temperature of the dataset, in coordination with wind speed and direction

# %%
# isolate the environmental temperature data
df.loc[df['name'] == 'wxt.env.temp']
# Out:
#                                  timestamp          name  value  \
# 87716  2023-07-02 12:00:00.029156535+00:00  wxt.env.temp   20.6
# 87717  2023-07-02 12:00:00.107252119+00:00  wxt.env.temp   20.6
# 87718  2023-07-02 12:00:00.206164123+00:00  wxt.env.temp   20.6
# 87719  2023-07-02 12:00:00.283311181+00:00  wxt.env.temp   20.6
# 87720  2023-07-02 12:00:00.364271449+00:00  wxt.env.temp   20.6
# ...                                    ...           ...    ...
# 131569 2023-07-02 12:59:59.600882716+00:00  wxt.env.temp   20.3
# 131570 2023-07-02 12:59:59.684669667+00:00  wxt.env.temp   20.3
# 131571 2023-07-02 12:59:59.760763484+00:00  wxt.env.temp   20.3
# 131572 2023-07-02 12:59:59.841247667+00:00  wxt.env.temp   20.3
# 131573 2023-07-02 12:59:59.920791677+00:00  wxt.env.temp   20.3
#
#                          meta.host       meta.job meta.missing  \
# 87716   000048b02d3ae277.ws-nxcore  waggle-wxt536      -9999.9
# 87717   000048b02d3ae277.ws-nxcore  waggle-wxt536      -9999.9
# 87718   000048b02d3ae277.ws-nxcore  waggle-wxt536      -9999.9
# 87719   000048b02d3ae277.ws-nxcore  waggle-wxt536      -9999.9
# 87720   000048b02d3ae277.ws-nxcore  waggle-wxt536      -9999.9
# ...                            ...            ...          ...
# 131569  000048b02d3ae277.ws-nxcore  waggle-wxt536      -9999.9
# 131570  000048b02d3ae277.ws-nxcore  waggle-wxt536      -9999.9
# 131571  000048b02d3ae277.ws-nxcore  waggle-wxt536      -9999.9
# 131572  000048b02d3ae277.ws-nxcore  waggle-wxt536      -9999.9
# 131573  000048b02d3ae277.ws-nxcore  waggle-wxt536      -9999.9
#
#                meta.node                                        meta.plugin  \
# 87716   000048b02d3ae277  registry.sagecontinuum.org/jrobrien/waggle-wxt...
# 87717   000048b02d3ae277  registry.sagecontinuum.org/jrobrien/waggle-wxt...
# 87718   000048b02d3ae277  registry.sagecontinuum.org/jrobrien/waggle-wxt...
# 87719   000048b02d3ae277  registry.sagecontinuum.org/jrobrien/waggle-wxt...
# 87720   000048b02d3ae277  registry.sagecontinuum.org/jrobrien/waggle-wxt...
# ...                  ...                                                ...
# 131569  000048b02d3ae277  registry.sagecontinuum.org/jrobrien/waggle-wxt...
# 131570  000048b02d3ae277  registry.sagecontinuum.org/jrobrien/waggle-wxt...
# 131571  000048b02d3ae277  registry.sagecontinuum.org/jrobrien/waggle-wxt...
# 131572  000048b02d3ae277  registry.sagecontinuum.org/jrobrien/waggle-wxt...
# 131573  000048b02d3ae277  registry.sagecontinuum.org/jrobrien/waggle-wxt...
#
#            meta.sensor      meta.task      meta.units meta.vsn meta.zone
# 87716   vaisala-wxt536  waggle-wxt536  degree Celsius     W08D      core
# 87717   vaisala-wxt536  waggle-wxt536  degree Celsius     W08D      core
# 87718   vaisala-wxt536  waggle-wxt536  degree Celsius     W08D      core
# 87719   vaisala-wxt536  waggle-wxt536  degree Celsius     W08D      core
# 87720   vaisala-wxt536  waggle-wxt536  degree Celsius     W08D      core
# ...                ...            ...             ...      ...       ...
# 131569  vaisala-wxt536  waggle-wxt536  degree Celsius     W08D      core
# 131570  vaisala-wxt536  waggle-wxt536  degree Celsius     W08D      core
# 131571  vaisala-wxt536  waggle-wxt536  degree Celsius     W08D      core
# 131572  vaisala-wxt536  waggle-wxt536  degree Celsius     W08D      core
# 131573  vaisala-wxt536  waggle-wxt536  degree Celsius     W08D      core
#
# [43858 rows x 13 columns]

# %%
fig, axs = plt.subplots(figsize=(12, 4))

# Define Format of how the date is displayed
date_form = DateFormatter("%Y-%m-%d \n %H:%M:%S")

# Note: Use the Pandas DataFrame 'loc' functionality to search the object for the ambient temp
df.loc[df['name'] == 'wxt.env.temp'].set_index('timestamp').value.plot(
                                           xlabel='UTC Time \n [HH:MM:SS]',
                                           ylabel='Ambient Temperature \n [Degree Celsius]',
                                           title='CROCUS Level 1 Node (W057) - Vaisala WXT536',
                                           ax=axs
                                          )

axs.xaxis.set_major_formatter(date_form)
axs.grid(True)

# %%
fig, axs = plt.subplots(figsize=(12, 4))

# Define Format of how the date is displayed
date_form = DateFormatter("%Y-%m-%d \n %H:%M:%S")

# Note: Use the Pandas DataFrame 'loc' functionality to search the object for the ambient temp
df.loc[df['name'] == 'wxt.wind.speed'].set_index('timestamp').value.plot(
                                           xlabel='UTC Time \n [HH:MM:SS]',
                                           ylabel='Wind Speed \n [meters per second]',
                                           title='CROCUS Level 1 Node (W057) - Vaisala WXT536',
                                           ax=axs,
                                           color='C0'
                                          )
# Set the left hand y-axis label and color to match variable displayed
axs.set_ylabel('Wind Speed \n [meters per second]', 
               color='C0',
               )
# Change left hand y-axis tick colors to match variable displayed
axs.tick_params(axis='y', labelcolor='C0')

ax2 = axs.twinx()  # instantiate a second axes that shares the same x-axis

# Note: Use the Pandas DataFrame 'loc' functionality to search the object for the ambient temp
df.loc[df['name'] == 'wxt.wind.direction'].set_index('timestamp').value.plot(
                                                xlabel='UTC Time \n [HH:MM:SS]',
                                                title='CROCUS Level 1 Node (W057) - Vaisala WXT536',
                                                ax=ax2,
                                                color='C1'
                                               )
ax2.set_ylabel('Wind Direction \n [Degrees from North]', 
               color='C1',
               )
ax2.tick_params(axis='y', labelcolor='C1')

axs.xaxis.set_major_formatter(date_form)
axs.grid(True)

# %% [markdown]
# ## Display Diurnal Temperature Cycle
#
# Let's Grab all temperature data available to visualize the daily cycle

# %% [markdown]
# <div class="admonition alert alert-info">
#     <p class="admonition-title" style="font-weight:bold">Info</p>
#     If you are only interested in a specific measurement,
#     you can also query specific variables using the 'name' filter
# </div>

# %%
# Query the SAGE data client to access the data; use 'name' filter

df_temp = sage_data_client.query(start="2023-07-02T00:00:00Z",
                                 end="2023-07-03T00:00:00Z", 
                                    filter={
                                        "name" : 'wxt.env.temp',
                                        "vsn": "W08D",
                                        "sensor": "vaisala-wxt536"
                                    }
)

# %%
df_temp
# Out:
#                                   timestamp          name  value  \
# 0       2023-07-02 00:00:00.045553673+00:00  wxt.env.temp   23.1
# 1       2023-07-02 00:00:00.139277863+00:00  wxt.env.temp   23.1
# 2       2023-07-02 00:00:00.247003531+00:00  wxt.env.temp   23.1
# 3       2023-07-02 00:00:00.333327344+00:00  wxt.env.temp   23.1
# 4       2023-07-02 00:00:00.413374638+00:00  wxt.env.temp   23.1
# ...                                     ...           ...    ...
# 1052501 2023-07-02 23:59:59.631203637+00:00  wxt.env.temp   17.9
# 1052502 2023-07-02 23:59:59.713241159+00:00  wxt.env.temp   17.9
# 1052503 2023-07-02 23:59:59.790870013+00:00  wxt.env.temp   17.9
# 1052504 2023-07-02 23:59:59.872975312+00:00  wxt.env.temp   17.9
# 1052505 2023-07-02 23:59:59.951280016+00:00  wxt.env.temp   17.9
#
#                           meta.host       meta.job meta.missing  \
# 0        000048b02d3ae277.ws-nxcore  waggle-wxt536      -9999.9
# 1        000048b02d3ae277.ws-nxcore  waggle-wxt536      -9999.9
# 2        000048b02d3ae277.ws-nxcore  waggle-wxt536      -9999.9
# 3        000048b02d3ae277.ws-nxcore  waggle-wxt536      -9999.9
# 4        000048b02d3ae277.ws-nxcore  waggle-wxt536      -9999.9
# ...                             ...            ...          ...
# 1052501  000048b02d3ae277.ws-nxcore  waggle-wxt536      -9999.9
# 1052502  000048b02d3ae277.ws-nxcore  waggle-wxt536      -9999.9
# 1052503  000048b02d3ae277.ws-nxcore  waggle-wxt536      -9999.9
# 1052504  000048b02d3ae277.ws-nxcore  waggle-wxt536      -9999.9
# 1052505  000048b02d3ae277.ws-nxcore  waggle-wxt536      -9999.9
#
#                 meta.node                                        meta.plugin  \
# 0        000048b02d3ae277  registry.sagecontinuum.org/jrobrien/waggle-wxt...
# 1        000048b02d3ae277  registry.sagecontinuum.org/jrobrien/waggle-wxt...
# 2        000048b02d3ae277  registry.sagecontinuum.org/jrobrien/waggle-wxt...
# 3        000048b02d3ae277  registry.sagecontinuum.org/jrobrien/waggle-wxt...
# 4        000048b02d3ae277  registry.sagecontinuum.org/jrobrien/waggle-wxt...
# ...                   ...                                                ...
# 1052501  000048b02d3ae277  registry.sagecontinuum.org/jrobrien/waggle-wxt...
# 1052502  000048b02d3ae277  registry.sagecontinuum.org/jrobrien/waggle-wxt...
# 1052503  000048b02d3ae277  registry.sagecontinuum.org/jrobrien/waggle-wxt...
# 1052504  000048b02d3ae277  registry.sagecontinuum.org/jrobrien/waggle-wxt...
# 1052505  000048b02d3ae277  registry.sagecontinuum.org/jrobrien/waggle-wxt...
#
#             meta.sensor      meta.task      meta.units meta.vsn meta.zone
# 0        vaisala-wxt536  waggle-wxt536  degree Celsius     W08D      core
# 1        vaisala-wxt536  waggle-wxt536  degree Celsius     W08D      core
# 2        vaisala-wxt536  waggle-wxt536  degree Celsius     W08D      core
# 3        vaisala-wxt536  waggle-wxt536  degree Celsius     W08D      core
# 4        vaisala-wxt536  waggle-wxt536  degree Celsius     W08D      core
# ...                 ...            ...             ...      ...       ...
# 1052501  vaisala-wxt536  waggle-wxt536  degree Celsius     W08D      core
# 1052502  vaisala-wxt536  waggle-wxt536  degree Celsius     W08D      core
# 1052503  vaisala-wxt536  waggle-wxt536  degree Celsius     W08D      core
# 1052504  vaisala-wxt536  waggle-wxt536  degree Celsius     W08D      core
# 1052505  vaisala-wxt536  waggle-wxt536  degree Celsius     W08D      core
#
# [1052506 rows x 13 columns]

# %%
fig, axs = plt.subplots(figsize=(12, 4))

# Define Format of how the date is displayed
date_form = DateFormatter("%Y-%m-%d \n %H:%M:%S")

# Note: Use the Pandas DataFrame 'loc' functionality to search the object for the ambient temp
df_temp.set_index('timestamp').value.plot(xlabel='UTC Time \n [HH:MM:SS]',
                                          ylabel='Ambient Temperature \n [Degree Celsius]',
                                          title='CROCUS Level 1 Node (W057) - Vaisala WXT536',
                                          ax=axs
                                          )

axs.xaxis.set_major_formatter(date_form)
axs.grid(True)

# %% [markdown]
# ## Save Your Selected Dataset

# %% [markdown]
# <div class="admonition alert alert-warning">
#     <p class="admonition-title" style="font-weight:bold">Warning</p>
#     Be careful! Saving data in a comma separated values (CSV) file format takes up a lot of space!
# </div>

# %%
# Instead of saving every value explored previously, I am just going to save the variable I am interested in (i.e. temperature)
# Comma Separated Values (CSV) files are common text files that can be read with any text editor (or Microsoft Excel / Mac Numbers)
df_temp.to_csv('wxt536_W08D_ambient_temp.csv')

# %%
# Let's check the size of that file using simple unix commands
# !ls -lh 'wxt536_W08D_ambient_temp.csv'
# Out:
# -rw-r--r--  1 mgrover  staff   242M Aug 15 08:28 wxt536_W08D_ambient_temp.csv

# %% [markdown]
# - 242M MB is a large file for just one environmental parameter.
# - It would be much larger if we saved all the observations for an hour (or day, or week, or month, etc)

# %% [markdown]
# <div class="admonition alert alert-info">
#     <p class="admonition-title" style="font-weight:bold">Info</p>
#     Pandas DataFrames support multiple file formats for saving data, including binary Parquet files. This allows us to compress the data and save space
# </div>

# %%
df_temp.to_parquet('wxt536_W08D_ambient_temp.parquet',
                   use_deprecated_int96_timestamps=True)

# %%
# Let's check the size of the parquet file
# !ls -lh 'wxt536_W08D_ambient_temp.parquet'
# Out:
# -rw-r--r--  1 mgrover  staff   7.2M Aug 15 08:28 wxt536_W08D_ambient_temp.parquet

# %% [markdown]
# - Only 7.2MB saving the same data as this format!
# - Less than 4% of the space taken up by the same data in CSV format!
